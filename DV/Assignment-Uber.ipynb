# %% [markdown]
# # **Assignment on Uber dataset**

# %% [markdown]
# **Load the dataset**

# %%
import pandas as pd
data=pd.read_csv("store_sales (1).csv")
data
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# 1    21   19
# 2    24    8
# ...

# %% [markdown]
# **Display basic info about dataset**

# %%
print(data.info())
print("*"*50)
print(data.describe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# None
# **************************************************
# <bound method NDFrame.describe of            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# ...

# %% [markdown]
# **Check for missing values**

# %%
missing_values = uber_data.isna().sum()
print(missing_values)
# Out:
# START_DATE*    0
# END_DATE*      1
# CATEGORY*      1
# START*         1
# STOP*          1
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %% [markdown]
# **Drop rows with missing values**

# %%
missing_values=uber_data.dropna()
print(missing_values)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# **fill missing values (propose column with unknown value)**

# %%
uber_data.loc[:,'PURPOSE*'] = uber_data['PURPOSE*'].fillna("Unknown")
print(uber_data)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# **Check and remove duplicates**

# %%
uber_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# 1155    False
# Length: 1156, dtype: bool

# %%
uber_data_cleaned = uber_data.drop_duplicates()
print(uber_data_cleaned)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# **Convert START_DATE and END_DATE to datetime**

# %% [markdown]
# **Total number of rides per category:**

# %%
uber_data.groupby("CATEGORY*").size()
# Out:
# CATEGORY*
# Business    1078
# Personal      77
# dtype: int64

# %% [markdown]
# **Total miles traveled for each purpose:**

# %%
uber_data.groupby("PURPOSE*")["MILES*"].sum()
# Out:
# PURPOSE*
# 0                  17098.2
# Airport/Travel        16.5
# Between Offices      197.0
# Charity ($)           15.1
# Commute              180.2
# Customer Visit      2089.5
# Errand/Supplies      508.0
# Meal/Entertain       911.7
# Meeting             2851.3
# Moving                18.2
# Temporary Site       523.7
# Name: MILES*, dtype: float64

# %% [markdown]
# **Average distance for business vs. personal rides:**

# %%
uber_data.groupby("PURPOSE*")["MILES*"].mean()
# Out:
# PURPOSE*
# 0                   33.992445
# Airport/Travel       5.500000
# Between Offices     10.944444
# Charity ($)         15.100000
# Commute            180.200000
# Customer Visit      20.688119
# Errand/Supplies      3.968750
# Meal/Entertain       5.698125
# Meeting             15.247594
# Moving               4.550000
# Temporary Site      10.474000
# Name: MILES*, dtype: float64

# %% [markdown]
# **Add a column for cost estimation (assuming $2 per mile):**

# %%
uber_data["cost_est"] = uber_data["MILES*"]*2
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*  cost_est
# 0          Fort Pierce      5.1   Meal/Entertain      10.2
# ...

# %% [markdown]
# **Filter rides longer than 50 miles:**

# %%
uber_data[uber_data["MILES*"]>=50]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 232    3/17/2016 12:52   3/17/2016 15:11  Business            Austin
# 251    3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 268    3/25/2016 13:24   3/25/2016 16:22  Business              Cary
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 295   04-02-2016 12:21  04-02-2016 14:47  Business         Kissimmee
# 296   04-02-2016 16:57  04-02-2016 18:09  Business     Daytona Beach
# 297   04-02-2016 19:38  04-02-2016 22:36  Business      Jacksonville
# 298   04-02-2016 23:11  04-03-2016 01:34  Business         Ridgeland
# 299   04-03-2016 02:00  04-03-2016 04:16  Business          Florence
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# ...

# %% [markdown]
# **Filter by specific purpose (e.g., meetings):**

# %%
uber_data["PURPOSE*"].value_counts()
# Out:
# PURPOSE*
# 0                  503
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: count, dtype: int64

# %% [markdown]
# **What is the total number of business trips versus personal trips?**

# %%
# Count the number of trips for Business and Personal
trip_counts = uber_data["CATEGORY*"].value_counts()

business_trips = trip_counts.get("Business")
personal_trips = trip_counts.get("Personal")

print(f"Total Business Trips: {business_trips}")
print(f"Total Personal Trips: {personal_trips}")
# Out:
# Total Business Trips: 1078
# Total Personal Trips: 77

# %% [markdown]
# **What percentage of trips are business versus personal?**

# %%
total_trips = business_trips + personal_trips

# %%
if total_trips > 0:
    business_percentage = (business_trips / total_trips) * 100
    personal_percentage = (personal_trips / total_trips) * 100
else:
    business_percentage = personal_percentage = 0

# Display the results
print(f"Total Business Trips: {business_trips} ({business_percentage:.2f}%)")
print(f"Total Personal Trips: {personal_trips} ({personal_percentage:.2f}%)")
# Out:
# Total Business Trips: 1078 (93.33%)
# Total Personal Trips: 77 (6.67%)
