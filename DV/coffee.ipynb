# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('coffeDataset.csv')
df
df.drop(columns='Date')
# Out:
#     Order_ID    Customer_Name     Product  Quantity  Price  Total
# 0          1         John Doe    Espresso         2   3.00   6.00
# 1          2       Jane Smith       Latte         1   4.50   4.50
# 2          3    Emily Johnson  Cappuccino         1   4.00   4.00
# 3          4      Michael Lee   Americano         2   3.00   6.00
# 4          5    Jessica Brown  Flat White         1   4.75   4.75
# 5          6     Chris Wilson       Mocha         1   5.00   5.00
# 6          7   Patricia Clark       Latte         2   4.50   9.00
# 7          8    Daniel Harris    Espresso         3   3.00   9.00
# 8          9    Olivia Martin  Cappuccino         1   4.00   4.00
# 9         10      James Lewis   Americano         1   3.00   3.00
# 10        11      Susan Allen       Latte         1   4.50   4.50
# 11        12      Kyle Walker       Mocha         2   5.00  10.00
# 12        13      Laura Scott  Flat White         1   4.75   4.75
# ...

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
target =  df['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
numrical_cols = df.select_dtypes(include=['number'])
y=numrical_cols['Survived']
x=numrical_cols.drop(columns='Survived',axis=1)

# %%
x.corr().round(2)
# Out:
#              PassengerId  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00   -0.04  0.04  -0.06  -0.00  0.01
# Pclass             -0.04    1.00 -0.37   0.08   0.02 -0.55
# Age                 0.04   -0.37  1.00  -0.31  -0.19  0.10
# SibSp              -0.06    0.08 -0.31   1.00   0.41  0.16
# Parch              -0.00    0.02 -0.19   0.41   1.00  0.22
# Fare                0.01   -0.55  0.10   0.16   0.22  1.00

# %%
sns.heatmap(x.corr().round(2), annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
data = {'difficulty':['Easy','medium','hard','medium','easy'],
        'marks' : [60,70,35,66,80]
}
data
# Out:
# {'difficulty': ['Easy', 'medium', 'hard', 'medium', 'easy'],
#  'marks': [60, 70, 35, 66, 80]}

# %%
pd.DataFrame(data)
# Out:
#   difficulty  marks
# 0       Easy     60
# 1     medium     70
# 2       hard     35
# 3     medium     66
# 4       easy     80

# %%
data
# Out:
# {'difficulty': ['Easy', 'medium', 'hard', 'medium', 'easy'],
#  'marks': [60, 70, 35, 66, 80]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   difficulty  marks
# 0       Easy     60
# 1     medium     70
# 2       hard     35
# 3     medium     66
# 4       easy     80

# %%
encode = LabelEncoder()
df['Difficulty_encoded'] =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 encode = LabelEncode()
#
# NameError: name 'LabelEncode' is not defined

# %%
data = {'color':['Red','Blue','Green','Blue','Red' ],
        'Test_score':[50,60,70,80,90]
}
df = pd.DataFrame(data)
df_encoded = pd.get_dummies(df,columns=['color'])
print(df_encoded)
# Out:
#    Test_score  color_Blue  color_Green  color_Red
# 0          50       False        False       True
# 1          60        True        False      False
# 2          70       False         True      False
# 3          80        True        False      False
# 4          90       False        False       True

# %%
https://teams.microsoft.com/v2/?meetingjoin=true#/l/meetup-join/19:meeting_Nzc2YzhkYTctNWNmOS00MjBmLWI2OWQtNjZlMzZkYTg5Nzkw@thread.v2/0?context=%7B%22Tid%22:%2244d8b453-bc45-44ea-ae2b-5c48de48fdf9%22,%22Oid%22:%22a5c746fb-1246-4155-ae47-6814888adbc4%22%7D&anon=true&deeplinkId=1e49808c-0294-45cc-aff2-bc04ee3d6778
