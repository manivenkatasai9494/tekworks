# %% [markdown]
# <h2>1.Probability Density Function (PDF) <br>
# (When Data is continuous like Height,Weight,Temperature)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import bernoulli

# %%
p=0.6

# %%
data = bernoulli.rvs(p,size=1000)

# %%
plt.bar([0,1],[sum(data==0), sum(data==1) ], color=['red','green'], tick_label=["Failure (0)","Success (1)"]  )
plt.xlabel("Outcome")
plt.ylabel("Frequnecy")
plt.title("Bernouli 0.6")
plt.show()

# %%
from scipy.stats import binom
import numpy as np

# %%
n = 10
p = 0.3 
x = np.arange(0,n+1)
pmf = binom.pmf(x,n,p)

# %%
from matplotlib.pylab import plt, poisson 


l = 3
x=np.arange(0,10)
pmf = poisson.pmf(x,l)

plt.bar(x,pmf,color='purple',alpha=0.7)
plt.xlabel("Number of call per min")
plt.ylabel("Probability")
plt.title("rftyuhjik")
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 6
#       4 l = 3
#       5 x=np.arange(0,10)
# ----> 6 pmf = poisson.pmf(x,l)
#       8 plt.bar(x,pmf,color='purple',alpha=0.7)
#       9 plt.xlabel("Number of call per min")
#
# AttributeError: '_cython_3_0_12.cython_function_or_method' object has no attribute 'pmf'

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
mu = 70
sigma = 10
x=np.linspace(mu - 4*sigma , mu + 4*sigma,100)
pdf = norm.pdf(x,mu,sigma)

plt.show(x,pdf,color='red',label=f"N({mu}, {sigma}**2  )")
plt.xlabel("exam score")
plt.ylabel("Probabolity")
plt.title("sigma")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 8
#       5 x=np.linspace(mu - 4*sigma , mu + 4*sigma,100)
#       6 pdf = norm.pdf(x,mu,sigma)
# ----> 8 plt.show(x,pdf,color='red',label=f"N({mu}, {sigma}**2  )")
#       9 plt.xlabel("exam score")
#      10 plt.ylabel("Probabolity")
#
# File d:\tekworks\prp\venv\lib\site-packages\matplotlib\pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# TypeError: show() got an unexpected keyword argument 'color'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)
income_data = np.random.exponential(scale=50,size=1000)

plt.figure(figsize=(8,4))
sns.histplot(income_data,bins=50,kde=True,color='r')
plt.title("Original Income Distribution (Skewd)")
plt.xlabel("dfgh")
plt.ylabel("dfghnm")
plt.show()

# %%
sample_means = []
n_samples = 1000
sample_size =  30

for _ in range(n_samples):
    sample = np.random.choice(income_data,size=sample_size)
    sample_means.append(np.mean(sample))

plt.figure(figsize=(8,4))
sns.histplot(sample_means,bins=50,kde=True,color="b")
plt.title(f"Sampling Distribution of Sample")
plt.xlabel("sample mean")
plt.ylabel("dcfvgbhnjm")
plt.show()
